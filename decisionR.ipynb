# %%
data <- read.csv("C:\\Users\\LENOVO\\Desktop\\creditcard.csv", header = TRUE,
                  stringsAsFactors = FALSE,
                  strip.white = TRUE ,
                  sep = ',')

# %%
library(rpart)
library(rattle)
 
rpart <- rpart(Class ~ V14+V10+V4+V17+V12, data=data, method="class",)

# plot decision tree
fancyRpartPlot(rpart, main="credit_card")
# Out:
# Plot with title "credit_card"
